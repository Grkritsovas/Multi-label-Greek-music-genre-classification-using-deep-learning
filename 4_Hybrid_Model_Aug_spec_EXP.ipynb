# %%
import os
os.environ["TF_XLA_FLAGS"] = "--tf_xla_enable_xla_devices=false"
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
os.environ["TF_CUDNN_USE_AUTOTUNE"] = "0"
import tensorflow as tf

gpus = tf.config.list_physical_devices('GPU')
if gpus:
    for gpu in gpus:
        tf.config.experimental.set_memory_growth(gpu, True)
tf.config.optimizer.set_jit(True)  # Enable XLA
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1743371786.204486   13965 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1743371786.226611   13965 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
import pandas as pd
import numpy as np
from glob import glob

# %%
from sklearn.model_selection import KFold
from sklearn.decomposition import TruncatedSVD
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import (accuracy_score, precision_recall_fscore_support, 
                             hamming_loss, f1_score, roc_auc_score)

from tensorflow.keras import layers, models
from tensorflow.keras import backend as K
from keras.callbacks import LearningRateScheduler, EarlyStopping, ModelCheckpoint
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.optimizers.schedules import CosineDecay
import gc

from tensorflow.keras.mixed_precision import set_global_policy
policy = tf.keras.mixed_precision.Policy('mixed_float16')
tf.keras.mixed_precision.set_global_policy(policy)
print("Mixed precision enabled with policy:", policy.name)
# Out:
# Mixed precision enabled with policy: mixed_float16

# %% [markdown]
# ### Helper functions to load the dataset

# %%
def get_feature_description():
    feature_description = {
        'mel_spectrogram': tf.io.FixedLenFeature([], tf.string),
        'labels': tf.io.VarLenFeature(tf.int64),
        'song_name': tf.io.FixedLenFeature([], tf.string),
        'segment_idx': tf.io.FixedLenFeature([], tf.int64),
        'total_segments': tf.io.FixedLenFeature([], tf.int64),
    }
    return feature_description

# %%
def parse_tfrecord_fn(example):
    feature_description = get_feature_description()
    example = tf.io.parse_single_example(example, feature_description)
    
    # Directly parse the float32 tensor
    mel_spec = tf.io.parse_tensor(example['mel_spectrogram'], out_type=tf.float32)
    
    current_shape = tf.shape(mel_spec)
    
    if tf.rank(mel_spec) != 2:
        # If not a 2D tensor, reshape it to [80, ?]
        mel_spec = tf.reshape(mel_spec, [80, -1])
        current_shape = tf.shape(mel_spec)
    
    # Crop or pad the time dimension to 650
    if current_shape[1] > 650:
        # Crop to [80, 650]
        mel_spec = mel_spec[:, :650]
    else:
        # Pad to [80, 650]
        paddings = [[0, 0], [0, 650 - current_shape[1]]]
        mel_spec = tf.pad(mel_spec, paddings, "CONSTANT", constant_values=0)
    
    mel_spec = tf.ensure_shape(mel_spec, [80, 650])

    mel_spec = (mel_spec - tf.reduce_mean(mel_spec)) / tf.math.reduce_std(mel_spec)
    
    # Add channel dimension for CNN input [80, 650] -> [80, 650, 1]
    mel_spec = tf.expand_dims(mel_spec, axis=-1)
    
    labels = tf.sparse.to_dense(example['labels'])
    
    return mel_spec, labels

# %%
def prepare_dataset(tfrecord_pattern, svd_components, batch_size=32, is_training=True):

    dataset = tf.data.Dataset.list_files(tfrecord_pattern, shuffle=is_training)
    
    # Use num_parallel_reads for good throughput
    dataset = tf.data.TFRecordDataset(
        dataset, 
        buffer_size=256*1024*1024,
        num_parallel_reads=tf.data.AUTOTUNE
    )
    
    dataset = dataset.map(parse_tfrecord_fn, num_parallel_calls=tf.data.AUTOTUNE)
    
    # Process SVD components 
    def add_svd_embeddings(mel, labels):
        labels_reshaped = tf.reshape(labels, [8])
        dense_labels = tf.matmul(tf.reshape(tf.cast(labels_reshaped, tf.float32), [1, 8]), 
                              svd_components,
                              transpose_b=True)[0]
        return mel, (dense_labels, labels_reshaped)
    
    dataset = dataset.map(add_svd_embeddings, num_parallel_calls=tf.data.AUTOTUNE)
    
    # Cache after preprocessing before batching
    dataset = dataset.cache()
    
    # Shuffle with a large buffer
    if is_training:
        dataset = dataset.shuffle(10000)
    
    dataset = dataset.batch(batch_size, drop_remainder=is_training)
    dataset = dataset.map(
        lambda x, y: (x, {'dense_output': y[0], 'binary_output': y[1]}),
        num_parallel_calls=tf.data.AUTOTUNE
    )
    if is_training:
        dataset = dataset.repeat()
    dataset = dataset.prefetch(tf.data.AUTOTUNE)
    return dataset

# %% [markdown]
# ### Model Architecture

# %%
def residual_block(x, filters, kernel_size=3, stride=1, activation='relu'):
    shortcut = x
    x = layers.Conv2D(filters, kernel_size, strides=stride, padding='same', 
                      kernel_initializer='he_normal')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation(activation)(x)
    
    
    x = layers.Conv2D(filters, kernel_size+2, strides=1, padding='same', 
                      kernel_initializer='he_normal')(x)
    x = layers.BatchNormalization()(x)
    
    # Adaptive shortcut connection
    if stride != 1 or shortcut.shape[-1] != filters:
        shortcut = layers.Conv2D(filters, 1, strides=stride, padding='same', 
                                 kernel_initializer='he_normal')(shortcut)
        shortcut = layers.BatchNormalization()(shortcut)
    
    x = layers.Add()([shortcut, x])
    x = layers.Activation(activation)(x)
    return x
def attention_layer(x, reduction_ratio=4):
    """ A CBAM-inspired attention layer with separate channel and spatial attention. """
    # 1) Channel Attention
    channel_avg = layers.GlobalAveragePooling2D()(x)  # shape: (batch, channels)
    channel_max = layers.GlobalMaxPooling2D()(x)      # shape: (batch, channels)

    # Shared MLP for both avg and max pools
    # (Typically 1 hidden Dense with 'reduction_ratio' + 1 final Dense -> out_dim = channels)
    hidden_dim = x.shape[-1] // reduction_ratio
    mlp = tf.keras.Sequential([
        layers.Dense(hidden_dim, activation='relu'),
        layers.Dense(x.shape[-1])  # linear layer, no activation
    ])

    # Pass both pooling results through the same MLP and sum
    avg_out = mlp(channel_avg)    # shape: (batch, channels)
    max_out = mlp(channel_max)    # shape: (batch, channels)
    channel_attention = layers.Activation('sigmoid')(avg_out + max_out)  # shape: (batch, channels)

    # Reshape to broadcast over (H, W)
    channel_attention = layers.Reshape((1, 1, x.shape[-1]))(channel_attention)
    # Multiply original feature map by channel attention
    x = layers.Multiply()([x, channel_attention])


    # 2) Spatial Attention
    # Compute mean and max along the channel axis
    avg_spatial = layers.Lambda(lambda f: tf.reduce_mean(f, axis=-1, keepdims=True))(x)  # (batch, H, W, 1)
    max_spatial = layers.Lambda(lambda f: tf.reduce_max(f, axis=-1, keepdims=True))(x)   # (batch, H, W, 1)

    # Concatenate along the channel dimension
    spatial_concat = layers.Concatenate(axis=-1)([avg_spatial, max_spatial])  # (batch, H, W, 2)

    # 7x7 Conv -> sigmoid
    spatial_attention = layers.Conv2D(filters=1, kernel_size=7, 
                                      padding='same', activation='sigmoid')(spatial_concat)
    # Multiply original feature map by spatial attention
    x = layers.Multiply()([x, spatial_attention])

    return x

# %%
def model_hybrid(input_shape, dense_dim, num_classes):
    inputs = layers.Input(shape=input_shape)
    
    # More gradual feature extraction
    x = layers.Conv2D(32, (3, 3), padding='same', kernel_initializer='he_normal')(inputs)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    
    # Progressive complexity with optional dropout
    x = residual_block(x, 64)
    x = layers.MaxPooling2D((2, 4))(x)
    x = layers.Dropout(0.15)(x)
    
    x = residual_block(x, 128)
    x = layers.MaxPooling2D((2, 4))(x)
    x = layers.Dropout(0.2)(x)
    
    x = residual_block(x, 256, stride=2)
    x = layers.AveragePooling2D((2, 4))(x)
    x = layers.Dropout(0.25)(x)
    
    x = attention_layer(x, reduction_ratio=4)
    x = layers.Dropout(0.3)(x)
    
    x = layers.GlobalAveragePooling2D()(x)
    
    x = layers.Dense(256, activation='relu', 
                     kernel_regularizer=tf.keras.regularizers.l2(0.001))(x)
    x = layers.Dropout(0.5)(x)
    
    x = layers.Dense(128, activation='selu', 
                     kernel_regularizer=tf.keras.regularizers.l2(0.0005))(x)
    x = layers.Dropout(0.3)(x)
    
    # Embeddings
    dense_embedding = layers.Dense(dense_dim, use_bias=True, 
                                   kernel_regularizer=tf.keras.regularizers.l2(0.0003))(x)
    dense_out = layers.Lambda(lambda t: tf.nn.l2_normalize(t, axis=-1), 
                               name='dense_output')(dense_embedding)
    binary_out = layers.Dense(8, activation='sigmoid', name='binary_output')(dense_embedding)
    
    return models.Model(inputs, [dense_out, binary_out])

# %% [markdown]
# #### Custom error functions

# %%
@tf.function
def custom_cosine_similarity(y_true, y_pred):
    dot_product = tf.reduce_sum(y_true * y_pred, axis=-1)
    norm_true = tf.sqrt(tf.reduce_sum(y_true ** 2, axis=-1))
    norm_pred = tf.sqrt(tf.reduce_sum(y_pred ** 2, axis=-1))
    # If norm_pred is too small, set similarity to 0 to avoid NaN
    cosine_sim = tf.where(norm_pred > 1e-8, dot_product / (norm_true * norm_pred + 1e-8), 0.0)
    return 1-cosine_sim  # range will be [0:2] instead of [-1,1]

# %%
@tf.function
def weighted_focal_loss(y_true, y_pred_logits, gamma=0.8, class_weights=None):
    # Get the dtype from inputs to maintain consistency
    dtype = y_pred_logits.dtype
    
    y_true = tf.cast(y_true, dtype=dtype)
    y_pred_logits = tf.clip_by_value(y_pred_logits, -4, 4)  # Prevent overflow
    def temperature_scaled_sigmoid(logits, temperature=1.5):
        scaled_logits = logits / temperature
        return tf.nn.sigmoid(scaled_logits)

    # scaled to avoid extreme values on the logits produced by sigmoid
    y_pred = temperature_scaled_sigmoid(y_pred_logits, temperature=1.5)
    #y_pred = tf.nn.sigmoid(y_pred_logits)
    
    bce = tf.nn.sigmoid_cross_entropy_with_logits(labels=y_true, logits=y_pred_logits)
    p_t = y_true * y_pred + (1 - y_true) * (1 - y_pred)
    
    focal_weight = tf.pow(1 - p_t, gamma)
    focal_bce = focal_weight * bce
    
    # Use class_weights passed as an argument
    if class_weights is not None:
        batch_size = tf.shape(y_true)[0]
        weights_0 = tf.cast(class_weights[:, 0][None, :], dtype=dtype)
        weights_1 = tf.cast(class_weights[:, 1][None, :], dtype=dtype)
        weights_0 = tf.reshape(weights_0, [1, -1])
        weights_1 = tf.reshape(weights_1, [1, -1])
        weights = tf.where(y_true == 1.0, weights_1, weights_0)
        weighted_focal_bce = focal_bce * weights
    else:
        weighted_focal_bce = focal_bce
    
    # Replace NaN with 0
    weighted_focal_bce = tf.where(tf.math.is_nan(weighted_focal_bce), tf.zeros_like(weighted_focal_bce), weighted_focal_bce)
    
    # Return with the same dtype as input
    return tf.reduce_mean(weighted_focal_bce, axis=-1)

# %%
train_files = tf.io.gfile.glob(
    "/home/georgios/Music Analysis/creating_spectrogram_batches/tfrecord_dataset/train/*.tfrecord"
)

# %%
train_files = train_files[:len(train_files)-2]
val_files = train_files[len(train_files)-2:]

# %%
# Load pre-computed class weights
class_weights_file = 'npy/class_weights_file.npy'
class_weights = np.load(class_weights_file)
print("Loaded pre-computed class weights:\n", class_weights)
# Out:
# Loaded pre-computed class weights:
#  [[0.17759454 0.52572024]
#  [0.12158575 1.6522636 ]
#  [0.15498619 0.67048377]
#  [0.12977105 1.1565845 ]
#  [0.15629521 0.6585534 ]
#  [0.24381228 3.246553  ]
#  [0.26550004 2.102881  ]
#  [0.11107654 4.626338  ]]

# %%
# Load the precomputed from the song level svd components:
svd_components = np.load("npy/svd_components_6.npy")

# %%
# Then use them to create the dataset with both dense and binary target labels.
train_dataset = prepare_dataset(train_files, svd_components, batch_size=32)

# %%
steps_per_epoch = 700

# %%
val_dataset = prepare_dataset(val_files, svd_components, batch_size=32, is_training=False)

# %%
# Check SVD components
print("SVD components shape:", svd_components.shape)
print("SVD components sample:", svd_components[0])  # values of first component
# Out:
# SVD components shape: (6, 8)
# SVD components sample: [0.68000436 0.11893529 0.4796936  0.14899106 0.48038375 0.09954965
#  0.17437015 0.00778061]

# %%
optimizer = tf.keras.optimizers.Adam(learning_rate=1e-3, clipnorm=1.0)
lr_scheduler = CosineDecay(initial_learning_rate=1e-4, decay_steps=33300)

# %%
len(svd_components)
# Out:
# 6

# %%
model = model_hybrid_ECA(input_shape=(80, 650, 1), dense_dim=len(svd_components), num_classes=8)

# %%
@tf.function #partial function with the class weights
def weighted_focal_loss_with_weights(y_true, y_pred):
    return weighted_focal_loss(y_true, y_pred, class_weights=class_weights)

# %%
# Compile the model with the modified loss function
model.compile(
    optimizer=optimizer,
    loss={
        'dense_output': custom_cosine_similarity,
        'binary_output': weighted_focal_loss_with_weights
    },
    loss_weights={
        'dense_output': 0.4,
        'binary_output': 0.8
    },
    metrics={
        'binary_output': [
            tf.keras.metrics.BinaryAccuracy(),
            tf.keras.metrics.F1Score(threshold=0.5, average='micro'),
            tf.keras.metrics.F1Score(threshold=0.5, average='macro')
        ]
    }
)

# %%
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 80, 650,   │          0 │ -                 │
# │ (InputLayer)        │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ cast (Cast)         │ (None, 80, 650,   │          0 │ input_layer[0][0] │
# │                     │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 80, 650,   │        320 │ cast[0][0]        │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 80, 650,   │        128 │ conv2d[0][0]      │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation          │ (None, 80, 650,   │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 80, 650,   │      9,248 │ activation[0][0]  │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 80, 650,   │        128 │ conv2d_1[0][0]    │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1        │ (None, 80, 650,   │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 80, 650,   │     25,632 │ activation_1[0][… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 80, 650,   │        128 │ conv2d_2[0][0]    │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 80, 650,   │          0 │ activation[0][0], │
# │                     │ 32)               │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_2        │ (None, 80, 650,   │          0 │ add[0][0]         │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 40, 162,   │          0 │ activation_2[0][… │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 40, 162,   │          0 │ max_pooling2d[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 20, 81,    │     18,496 │ dropout[0][0]     │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 20, 81,    │        256 │ conv2d_3[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_3        │ (None, 20, 81,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 20, 81,    │      2,112 │ dropout[0][0]     │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 20, 81,    │    102,464 │ activation_3[0][… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 20, 81,    │        256 │ conv2d_5[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 20, 81,    │        256 │ conv2d_4[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 20, 81,    │          0 │ batch_normalizat… │
# │                     │ 64)               │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_4        │ (None, 20, 81,    │          0 │ add_1[0][0]       │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ eca_layer           │ (None, 20, 81,    │          3 │ activation_4[0][… │
# │ (ECALayer)          │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 10, 20,    │          0 │ eca_layer[0][0]   │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 10, 20,    │          0 │ max_pooling2d_1[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 5, 10,     │     73,856 │ dropout_1[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 5, 10,     │        512 │ conv2d_6[0][0]    │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_5        │ (None, 5, 10,     │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 5, 10,     │      8,320 │ dropout_1[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 5, 10,     │    409,728 │ activation_5[0][… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 5, 10,     │        512 │ conv2d_8[0][0]    │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 5, 10,     │        512 │ conv2d_7[0][0]    │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, 5, 10,     │          0 │ batch_normalizat… │
# │                     │ 128)              │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_6        │ (None, 5, 10,     │          0 │ add_2[0][0]       │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ average_pooling2d   │ (None, 2, 2, 128) │          0 │ activation_6[0][… │
# │ (AveragePooling2D)  │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 2, 2, 128) │          0 │ average_pooling2… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 128)       │          0 │ dropout_2[0][0]   │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 256)       │     33,024 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_3 (Dropout) │ (None, 256)       │          0 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_embedding     │ (None, 6)         │      1,542 │ dropout_3[0][0]   │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 262)       │          0 │ dropout_3[0][0],  │
# │ (Concatenate)       │                   │            │ dense_embedding[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_output        │ (None, 6)         │          0 │ dense_embedding[… │
# │ (Lambda)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ binary_output       │ (None, 8)         │      2,104 │ concatenate[0][0] │
# │ (Dense)             │                   │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 689,537 (2.63 MB)
#  Trainable params: 688,193 (2.63 MB)
#  Non-trainable params: 1,344 (5.25 KB)

# %%
callbacks = [
    EarlyStopping(
        monitor='val_binary_output_f1_score_1',
        patience=7,
        restore_best_weights=True,
        mode = 'max',
        verbose=1
    ),
    ModelCheckpoint(
        filepath='saved_models/best_hybrid_model_cbam.keras',
        monitor='val_binary_output_f1_score_1',
        mode = 'max',
        save_best_only=True,
        verbose=1
    ),

    tf.keras.callbacks.ReduceLROnPlateau(
    monitor='loss',
    factor=0.5,
    patience=1,
    min_lr=1e-6,
    verbose=1
)]

# %%
# Train the model
history = model.fit(
    train_dataset, 
    epochs=90,
    callbacks= callbacks,
    steps_per_epoch = steps_per_epoch*2,
    validation_data = val_dataset
)
# Out:
# Epoch 1/90
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1743372218.614359   14181 service.cc:148] XLA service 0x7f8df8009040 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1743372218.614615   14181 service.cc:156]   StreamExecutor device (0): NVIDIA GeForce RTX 4070 Laptop GPU, Compute Capability 8.9
# I0000 00:00:1743372218.633693   14181 cuda_dnn.cc:529] Loaded cuDNN version 90300
# I0000 00:00:1743372218.680051   14181 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 1400/1400 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - binary_output_binary_accuracy: 0.6930 - binary_output_f1_score: 0.5132 - binary_output_f1_score_1: 0.4923 - binary_output_loss: 0.1317 - dense_output_loss: 0.3257 - loss: 0.2971
# Epoch 1: val_binary_output_f1_score_1 improved from -inf to 0.47260, saving model to saved_models/best_hybrid_model_cbam.keras
# /home/georgios/miniconda3/envs/tf-gpu/lib/python3.11/site-packages/keras/src/trainers/epoch_iterator.py:151: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# 1400/1400 ━━━━━━━━━━━━━━━━━━━━ 156s 62ms/step - binary_output_binary_accuracy: 0.6930 - binary_output_f1_score: 0.5132 - binary_output_f1_score_1: 0.4923 - binary_output_loss: 0.1316 - dense_output_loss: 0.3256 - loss: 0.2971 - val_binary_output_binary_accuracy: 0.7562 - val_binary_output_f1_score: 0.6065 - val_binary_output_f1_score_1: 0.4726 - val_binary_output_loss: 0.1284 - val_dense_output_loss: 0.2539 - val_loss: 0.2121 - learning_rate: 0.0010
# Epoch 2/90
# 1400/1400 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - binary_output_binary_accuracy: 0.7969 - binary_output_f1_score: 0.6359 - binary_output_f1_score_1: 0.6249 - binary_output_loss: 0.1205 - dense_output_loss: 0.2240 - loss: 0.1930
# Epoch 2: val_binary_output_f1_score_1 improved from 0.47260 to 0.48852, saving model to saved_models/best_hybrid_model_cbam.keras
# 1400/1400 ━━━━━━━━━━━━━━━━━━━━ 76s 54ms/step - binary_output_binary_accuracy: 0.7970 - binary_output_f1_score: 0.6359 - binary_output_f1_score_1: 0.6250 - binary_output_loss: 0.1205 - dense_output_loss: 0.2239 - loss: 0.1930 - val_binary_output_binary_accuracy: 0.7757 - val_binary_output_f1_score: 0.6194 - val_binary_output_f1_score_1: 0.4885 - val_binary_output_loss: 0.1252 - val_dense_output_loss: 0.2614 - val_loss: 0.2111 - learning_rate: 0.0010
# Epoch 3/90
# 1400/1400 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - binary_output_binary_accuracy: 0.8253 - binary_output_f1_score: 0.6757 - binary_output_f1_score_1: 0.6653 - binary_output_loss: 0.1175 - dense_output_loss: 0.1896 - loss: 0.1761
# Epoch 3: val_binary_output_f1_score_1 did not improve from 0.48852
# 1400/1400 ━━━━━━━━━━━━━━━━━━━━ 76s 54ms/step - binary_output_binary_accuracy: 0.8253 - binary_output_f1_score: 0.6757 - binary_output_f1_score_1: 0.6653 - binary_output_loss: 0.1175 - dense_output_loss: 0.1896 - loss: 0.1761 - val_binary_output_binary_accuracy: 0.7487 - val_binary_output_f1_score: 0.5566 - val_binary_output_f1_score_1: 0.4547 - val_binary_output_loss: 0.1384 - val_dense_output_loss: 0.3641 - val_loss: 0.2631 - learning_rate: 0.0010
# Epoch 4/90
# 1400/1400 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - binary_output_binary_accuracy: 0.8442 - binary_output_f1_score: 0.7068 - binary_output_f1_score_1: 0.6931 - binary_output_loss: 0.1150 - dense_output_loss: 0.1649 - loss: 0.1641
# Epoch 4: val_binary_output_f1_score_1 improved from 0.48852 to 0.52876, saving model to saved_models/best_hybrid_model_cbam.keras
# 1400/1400 ━━━━━━━━━━━━━━━━━━━━
# Epoch 29: early stopping
# Restoring model weights from the end of the best epoch: 22.

# %% [markdown]
# ### Evaluating loss, accuracy and f1 training/validation graphs

# %%
import matplotlib.pyplot as plt

history_dict = history.history
Accuracy = history_dict['binary_output_binary_accuracy']
Val_Accuracy = history_dict['val_binary_output_binary_accuracy']
plt.figure(num=1, figsize=(15,7))
plt.plot(Accuracy,'bo',label='Training accuracy')
plt.plot(Val_Accuracy,'b',label='Validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show();

# %%
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
# summarize history for accuracy
plt.plot(history.history['binary_output_f1_score'])
plt.plot(history.history['val_binary_output_f1_score'])
plt.title('model f1 score logs')
plt.ylabel('f1 score')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
# summarize history for accuracy
plt.plot(history.history['binary_output_f1_score_1'])
plt.plot(history.history['val_binary_output_f1_score_1'])
plt.title('model f1 score macro logs')
plt.ylabel('f1 score macro')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %% [markdown]
# ### Testing the model

# %%
model = model_hybrid_ECA(input_shape=(80, 650, 1), dense_dim=6, num_classes=8)

# %%
model.load_weights("saved_models/best_hybrid_model_cbam.keras")

# %%
model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1       │ (None, 80, 650,   │          0 │ -                 │
# │ (InputLayer)        │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ cast_1 (Cast)       │ (None, 80, 650,   │          0 │ input_layer_1[0]… │
# │                     │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 80, 650,   │        320 │ cast_1[0][0]      │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 80, 650,   │        128 │ conv2d_9[0][0]    │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_7        │ (None, 80, 650,   │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 80, 650,   │      9,248 │ activation_7[0][… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 80, 650,   │        128 │ conv2d_10[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_8        │ (None, 80, 650,   │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 80, 650,   │     25,632 │ activation_8[0][… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 80, 650,   │        128 │ conv2d_11[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_3 (Add)         │ (None, 80, 650,   │          0 │ activation_7[0][… │
# │                     │ 32)               │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_9        │ (None, 80, 650,   │          0 │ add_3[0][0]       │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_2     │ (None, 40, 162,   │          0 │ activation_9[0][… │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_4 (Dropout) │ (None, 40, 162,   │          0 │ max_pooling2d_2[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, 20, 81,    │     18,496 │ dropout_4[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 20, 81,    │        256 │ conv2d_12[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_10       │ (None, 20, 81,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, 20, 81,    │      2,112 │ dropout_4[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, 20, 81,    │    102,464 │ activation_10[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 20, 81,    │        256 │ conv2d_14[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 20, 81,    │        256 │ conv2d_13[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_4 (Add)         │ (None, 20, 81,    │          0 │ batch_normalizat… │
# │                     │ 64)               │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_11       │ (None, 20, 81,    │          0 │ add_4[0][0]       │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ eca_layer_1         │ (None, 20, 81,    │          3 │ activation_11[0]… │
# │ (ECALayer)          │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_3     │ (None, 10, 20,    │          0 │ eca_layer_1[0][0] │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_5 (Dropout) │ (None, 10, 20,    │          0 │ max_pooling2d_3[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_15 (Conv2D)  │ (None, 5, 10,     │     73,856 │ dropout_5[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 5, 10,     │        512 │ conv2d_15[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_12       │ (None, 5, 10,     │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_17 (Conv2D)  │ (None, 5, 10,     │      8,320 │ dropout_5[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_16 (Conv2D)  │ (None, 5, 10,     │    409,728 │ activation_12[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 5, 10,     │        512 │ conv2d_17[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 5, 10,     │        512 │ conv2d_16[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_5 (Add)         │ (None, 5, 10,     │          0 │ batch_normalizat… │
# │                     │ 128)              │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_13       │ (None, 5, 10,     │          0 │ add_5[0][0]       │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ average_pooling2d_1 │ (None, 2, 2, 128) │          0 │ activation_13[0]… │
# │ (AveragePooling2D)  │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_6 (Dropout) │ (None, 2, 2, 128) │          0 │ average_pooling2… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 128)       │          0 │ dropout_6[0][0]   │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 256)       │     33,024 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_7 (Dropout) │ (None, 256)       │          0 │ dense_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_embedding     │ (None, 6)         │      1,542 │ dropout_7[0][0]   │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 262)       │          0 │ dropout_7[0][0],  │
# │ (Concatenate)       │                   │            │ dense_embedding[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_output        │ (None, 6)         │          0 │ dense_embedding[… │
# │ (Lambda)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ binary_output       │ (None, 8)         │      2,104 │ concatenate_1[0]… │
# │ (Dense)             │                   │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 689,537 (2.63 MB)
#  Trainable params: 688,193 (2.63 MB)
#  Non-trainable params: 1,344 (5.25 KB)

# %%
model.compile(
    optimizer=optimizer,
    loss={
        'dense_output': custom_cosine_similarity,
        'binary_output': weighted_focal_loss_with_weights
    },
    loss_weights={
        'dense_output': 0.4,
        'binary_output': 0.8
    },
    metrics={
        'binary_output': [
            tf.keras.metrics.BinaryAccuracy(),
            tf.keras.metrics.F1Score(threshold=0.5, average='micro'),
            tf.keras.metrics.F1Score(threshold=0.5, average='macro')
        ]
    }
)

# %%
# Prepare test dataset
test_files = tf.io.gfile.glob("/home/georgios/Music Analysis/creating_spectrogram_batches/tfrecord_dataset/test/*.tfrecord")
test_dataset = prepare_dataset(test_files, svd_components, batch_size=64, is_training=False)

# %%
# Evaluate the model on test data
print("Evaluating model on test data...")
evaluation = model.evaluate(test_dataset, steps=71)
# Out:
# Evaluating model on test data...
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 13s 26ms/step - binary_output_binary_accuracy: 0.8315 - binary_output_f1_score: 0.6246 - binary_output_f1_score_1: 0.6156 - binary_output_loss: 0.1250 - dense_output_loss: 0.2919 - loss: 0.2228

# %%
# Print overall evaluation metrics
metric_names = ['loss', 'dense_output_loss', 'binary_output_loss', 
                'binary_output_binary_accuracy', 'binary_output_f1_score_micro', 
                'binary_output_f1_score_macro']
for i, metric in enumerate(metric_names):
    print(f"{metric}: {evaluation[i]}")
# Out:
# loss: 0.2267502099275589
# dense_output_loss: 0.30433404445648193
# binary_output_loss: 0.12345173209905624
# binary_output_binary_accuracy: 0.8227227330207825
# binary_output_f1_score_micro: 0.6081684231758118
# binary_output_f1_score_macro: 0.6044594049453735

# %%
# Detailed evaluation on binary predictions
print("\nDetailed genre classification evaluation:")

# Get predictions
all_true_labels = []
all_predictions = []

for x_batch, y_batch in test_dataset:
    # Get predictions
    _, y_pred = model.predict(x_batch)
    # Convert predictions to binary using threshold 0.5
    y_pred_binary = (y_pred > 0.5).astype(np.float32)
    # Extract true labels
    y_true = y_batch['binary_output'].numpy()
    
    all_true_labels.append(y_true)
    all_predictions.append(y_pred_binary)
# Out:
# Detailed genre classification evaluation:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step

# %%
# Concatenate all batches
y_true = np.vstack(all_true_labels)
y_pred = np.vstack(all_predictions)

# Calculate metrics per genre
genre_names = ['LAIKO', 'REMPETIKO', 'ENTEXNO', 'ROCK', 'Mod LAIKO', 'POP', 'ENALLAKTIKO', 'HIPHOP/RNB']

print("\nPer-genre evaluation metrics:")
print("Genre\t\tF1\tPrecision\tRecall\tAccuracy\tAUC")
print("-" * 70)

for i, genre in enumerate(genre_names):
    # Calculate metrics
    precision, recall, f1, _ = precision_recall_fscore_support(
        y_true[:, i], y_pred[:, i], average='binary')
    accuracy = accuracy_score(y_true[:, i], y_pred[:, i])
    
    # Calculate AUC (needs raw probabilities)
    _, y_pred_proba = model.predict(test_dataset, steps=71)
    auc = roc_auc_score(y_true[:, i], y_pred_proba[:, i])
    
    # Print with alignment
    genre_padded = genre + (" " * (15 - len(genre)))
    print(f"{genre_padded}\t{f1:.3f}\t{precision:.3f}\t\t{recall:.3f}\t{accuracy:.3f}\t\t{auc:.3f}")
# Out:
# Per-genre evaluation metrics:
# Genre		F1	Precision	Recall	Accuracy	AUC
# ----------------------------------------------------------------------
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step
# LAIKO          	0.712	0.738		0.688	0.801		0.833
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step
# REMPETIKO      	0.702	0.617		0.813	0.924		0.954
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step
# ENTEXNO        	0.563	0.597		0.532	0.741		0.770
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step
# ROCK           	0.665	0.567		0.804	0.851		0.907
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step
# Mod LAIKO      	0.630	0.533		0.770	0.707		0.786
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step
# POP            	0.443	0.431		0.456	0.846		0.773
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step
# ENALLAKTIKO    	0.456	0.406		0.520	0.745		0.747
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step
# HIPHOP/RNB     	0.665	0.670		0.661	0.966		0.941

# %%
# Calculate overall metrics
print("\nOverall metrics:")
overall_precision, overall_recall, overall_f1, _ = precision_recall_fscore_support(
    y_true.flatten(), y_pred.flatten(), average='binary')
overall_accuracy = accuracy_score(y_true.flatten(), y_pred.flatten())
overall_hamming = hamming_loss(y_true, y_pred)

print(f"Overall F1 Score: {overall_f1:.3f}")
print(f"Overall Precision: {overall_precision:.3f}")
print(f"Overall Recall: {overall_recall:.3f}")
print(f"Overall Accuracy: {overall_accuracy:.3f}")
print(f"Hamming Loss: {overall_hamming:.3f}")
# Out:
# Overall metrics:
# Overall F1 Score: 0.608
# Overall Precision: 0.567
# Overall Recall: 0.656
# Overall Accuracy: 0.823
# Hamming Loss: 0.177

# %%
# Calculate exact match ratio (all genres predicted correctly)
exact_matches = np.all(y_true == y_pred, axis=1).mean()
print(f"Exact Match Ratio: {exact_matches:.3f}")
# Out:
# Exact Match Ratio: 0.228

# %%
# Confusion matrix for multi-label classification
print("\nLabel correlation analysis:")
print("Analyzing how well the model captures label relationships...")

# correlation matrices for true labels and predictions
true_corr = np.corrcoef(y_true.T)
pred_corr = np.corrcoef(y_pred.T)

# mean absolute error between correlation matrices
corr_mae = np.abs(true_corr - pred_corr).mean()
print(f"Correlation Matrix MAE: {corr_mae:.3f}")
# Out:
# Label correlation analysis:
# Analyzing how well the model captures label relationships...
# Correlation Matrix MAE: 0.070

# %%
# Visualize results
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

# Plot confusion matrix for each genre
fig, axes = plt.subplots(2, 4, figsize=(20, 10))
axes = axes.flatten()
cms = []

for i, (genre, ax) in enumerate(zip(genre_names, axes)):
    cm = confusion_matrix(y_true[:, i], y_pred[:, i])
    cms.append(cm)
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', ax=ax)
    ax.set_title(f'Confusion Matrix: {genre}')
    ax.set_xlabel('Predicted')
    ax.set_ylabel('True')
    
plt.tight_layout()
plt.show();

# %%
y_true.shape
# Out:
# (4512, 8)

# %%
cm = tf.math.confusion_matrix(y_true[:,7], y_pred[:,2])

sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
ax.set_title(f'Confusion Matrix: {genre}')
ax.set_xlabel('Predicted')
ax.set_ylabel('True')
plt.tight_layout() 
plt.show();

# %%
for cm in cms:
    print(cm)
# Out:
# [[2507  394]
#  [ 502 1109]]
# [[3763  251]
#  [  93  405]]
# [[2593  507]
#  [ 661  751]]
# [[3173  509]
#  [ 163  667]]
# [[2068  985]
#  [ 336 1123]]
# [[3543  364]
#  [ 329  276]]
# [[2881  704]
#  [ 445  482]]
# [[4203   76]
#  [  79  154]]

# %%
# correlation matrices
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(18, 8))
sns.heatmap(true_corr, annot=True, fmt='.2f', cmap='coolwarm', ax=ax1, 
            xticklabels=genre_names, yticklabels=genre_names)
ax1.set_title('True Label Correlations')

sns.heatmap(pred_corr, annot=True, fmt='.2f', cmap='coolwarm', ax=ax2, 
            xticklabels=genre_names, yticklabels=genre_names)
ax2.set_title('Predicted Label Correlations')

plt.tight_layout()
plt.show();

# %%
# Create a new model that outputs only the dense embeddings
embedding_model = tf.keras.Model(inputs=model.input, outputs=model.get_layer("dense_output").output)

# Get the embeddings
dense_embeddings = embedding_model.predict(test_dataset, batch_size=64, steps=71)
# Out:
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 4s 35ms/step

# %%
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Run t-SNE
tsne = TSNE(n_components=2, perplexity=30, learning_rate=200, random_state=42)
tsne_results = TSNE(n_components=2, perplexity=30).fit_transform(dense_embeddings)

# %%
# Get most prominent label for coloring with argmax
single_label_mask = np.sum(y_true, axis=1) == 1
x_embedded_filtered = tsne_results[single_label_mask]
y_labels = np.argmax(y_true[single_label_mask], axis=1)

plt.figure(figsize=(10, 8))
palette = sns.color_palette("hsv", len(np.unique(y_labels)))

genre_names = ['LAIKO', 'REMPETIKO', 'ENTEXNO', 'ROCK', 'Mod LAIKO', 'POP', 'ENALLAKTIKO', 'HIPHOP/RNB']
y_labels_named = [genre_names[i] for i in y_labels]

sns.scatterplot(
    x=x_embedded_filtered[:, 0],
    y=x_embedded_filtered[:, 1],
    hue=y_labels_named,
    palette="Set1",  # updated for better color contrast
    alpha=0.7,
    s=50,
    edgecolor='k'
)


plt.title("2D Projection of Dense Embeddings")
plt.xlabel("Dim 1")
plt.ylabel("Dim 2")
plt.legend(title="Genres", bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
import umap.umap_ as umap

reducer = umap.UMAP(n_components=6, random_state=42)
umap_results = reducer.fit_transform(dense_embeddings)

sns.scatterplot(
    x=umap_results[single_label_mask][:, 0],
    y=umap_results[single_label_mask][:, 1],
    hue=y_labels_named,
    palette="Set1",
    alpha=0.7,
    s=50,
    edgecolor='k'
)
plt.title("UMAP Projection of Dense Embeddings")
plt.xlabel("UMAP 1")
plt.ylabel("UMAP 2")
plt.legend(title="Genres", bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()
# Out:
# /home/georgios/miniconda3/envs/tf-gpu/lib/python3.11/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /home/georgios/miniconda3/envs/tf-gpu/lib/python3.11/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=6)
pca_results = pca.fit_transform(dense_embeddings)

print(f"Explained variance ratio: {pca.explained_variance_ratio_}")  # see how much info is preserved

sns.scatterplot(
    x=pca_results[single_label_mask][:, 0],
    y=pca_results[single_label_mask][:, 1],
    hue=y_labels_named,
    palette="Set1",
    alpha=0.8,
    s=250,
    edgecolor='k'
)
plt.title("PCA Projection of Dense Embeddings")
plt.xlabel("Principal Component 1")
plt.ylabel("Principal Component 2")
plt.legend(title="Genres", bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show();
# Out:
# Explained variance ratio: [0.3428371  0.30550522 0.15483204 0.09920075 0.08581013 0.01181475]

# %%
import pandas as pd
pca_1 = pca_results[single_label_mask][:, 0]

df = pd.DataFrame({
    'PC1': pca_1,
    'Genre': y_labels_named
})

sns.boxplot(data=df, x='Genre', y='PC1')
plt.xticks(rotation=45)
plt.title("Distribution of Principal Component 1 by Genre")
plt.show()

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
dense_embeddings_filtered = dense_embeddings[single_label_mask]

lda = LDA(n_components=6)
lda_results = lda.fit_transform(dense_embeddings_filtered, y_labels)

sns.scatterplot(
    x=lda_results[:, 0],
    y=lda_results[:, 1],
    hue=y_labels_named,
    palette="Set1",
    alpha=0.7,
    s=40,
    edgecolor='k'
)
plt.title("LDA Projection of Dense Embeddings")
plt.xlabel("LDA Component 1")
plt.ylabel("LDA Component 2")
plt.legend(title="Genres", bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
val_preds = model.predict(test_dataset)
val_labels = np.concatenate([y['binary_output'].numpy() for _, y in test_dataset.take(71)])

optimal_thresholds = []
for genre in range(8):
    best_f1, best_thresh = 0, 0
    for thresh in np.arange(0.1, 0.9, 0.05):
        f1 = f1_score(val_labels[:, genre], val_preds[1][:, genre] > thresh)
        if f1 > best_f1:
            best_f1, best_thresh = f1, thresh
    optimal_thresholds.append(best_thresh.round(2))
    print(f"Genre {genre}: Threshold = {best_thresh}, F1 = {best_f1}")
# Out:
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step
# /home/georgios/miniconda3/envs/tf-gpu/lib/python3.11/site-packages/keras/src/trainers/epoch_iterator.py:151: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# Genre 0: Threshold = 0.30000000000000004, F1 = 0.7165109034267912
# Genre 1: Threshold = 0.8500000000000002, F1 = 0.7102115915363385
# Genre 2: Threshold = 0.15000000000000002, F1 = 0.5887388870595983
# Genre 3: Threshold = 0.8500000000000002, F1 = 0.6751381215469613
# Genre 4: Threshold = 0.45000000000000007, F1 = 0.6304106548279689
# Genre 5: Threshold = 0.45000000000000007, F1 = 0.4449685534591195
# Genre 6: Threshold = 0.1, F1 = 0.4760076775431862
# Genre 7: Threshold = 0.30000000000000004, F1 = 0.6906187624750499

# %%
optimal_thresholds
# Out:
# [0.3, 0.85, 0.15, 0.85, 0.45, 0.45, 0.1, 0.3]

# %%
i = 0
found_better = False
for best_thresh in optimal_thresholds:
    for thresh in np.arange(max(0.05, best_thresh - 0.05), min(0.95, best_thresh + 0.05), 0.01):
        f1 = f1_score(val_labels[:, genre], val_preds[1][:, genre] > thresh)
        if f1 > best_f1:
            best_f1, best_thresh_finetuned = f1, thresh
            found_better = True
    if found_better:
        optimal_thresholds[i] = best_thresh_finetuned
    found_better = False
    i += 1

# %%
optimal_thresholds
# Out:
# [0.27, 0.85, 0.15, 0.85, 0.45, 0.45, 0.1, 0.3]

# %%
optimal_thresholds = [0.5]*8

# %%
# Get predictions from the test dataset
y_pred = model.predict(test_dataset)  # Shape: [2, num_samples, ...]
binary_preds = y_pred[1]  # Shape: [num_samples, 8]

# Convert to binary predictions using per-genre thresholds
thresholds_array = np.array(optimal_thresholds)  # Shape: [8]
binary_predictions = (binary_preds > thresholds_array).astype(int)  # Shape: [num_samples, 8]
# Out:
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step
# /home/georgios/miniconda3/envs/tf-gpu/lib/python3.11/site-packages/keras/src/trainers/epoch_iterator.py:151: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()

# %%
y_true = np.concatenate([y['binary_output'].numpy() for _, y in test_dataset.take(71)])  # Shape: [num_samples, 8]

# Compute macro F1 score
macro_f1 = f1_score(y_true, binary_predictions, average='macro')
print(f"Macro F1 Score with optimal thresholds: {macro_f1}")

# Optionally, per-genre F1 scores
per_genre_f1 = [f1_score(y_true[:, i], binary_predictions[:, i]) for i in range(8)]
for i, f1 in enumerate(per_genre_f1):
    print(f"Genre {i}: F1 = {f1}")
# Out:
# Macro F1 Score with optimal thresholds: 0.6044594492038253
# Genre 0: F1 = 0.7118535175072278
# Genre 1: F1 = 0.7019064124783362
# Genre 2: F1 = 0.5627575871112777
# Genre 3: F1 = 0.6646736422521176
# Genre 4: F1 = 0.6296607793664144
# Genre 5: F1 = 0.4433734939759036
# Genre 6: F1 = 0.4562233790818741
# Genre 7: F1 = 0.6652267818574514

# %%
y_true[0] #genre_names = ['LAIKO', 'REMPETIKO', 'ENTEXNO', 'ROCK', 'Mod LAIKO', 'POP', 'ENALLAKTIKO', 'HIPHOP/RNB']
# Out:
# array([0, 0, 0, 1, 0, 0, 1, 0])

# %%
y_pred[0]
# Out:
# array([[ 0.5454 , -0.1489 ,  0.769  ,  0.2272 ,  0.1527 ,  0.1176 ],
#        [ 0.3823 ,  0.7954 , -0.04266, -0.2384 ,  0.3948 ,  0.08215],
#        [ 0.359  ,  0.5117 ,  0.521  , -0.427  , -0.3845 ,  0.0895 ],
#        ...,
#        [ 0.4316 ,  0.3389 ,  0.665  , -0.2441 , -0.4346 ,  0.0874 ],
#        [ 0.6787 , -0.0902 , -0.2715 , -0.502  , -0.0671 , -0.4495 ],
#        [ 0.6094 , -0.2357 ,  0.721  ,  0.1554 ,  0.1539 ,  0.065  ]],
#       dtype=float16)

# %%
#optimal_thresholds = [0.16, 0.27, 0.07, 0.89, 0.997, 0.988, 1.0, 0.77]
optimal_thresholds = [0.27, 0.85, 0.15, 0.85, 0.45, 0.45, 0.1, 0.3]
thresholds_array = np.array(optimal_thresholds)
#genre_names = ['LAIKO', 'REMPETIKO', 'ENTEXNO', 'ROCK', 'Mod LAIKO', 'POP', 'ENALLAKTIKO', 'HIPHOP/RNB']
# Apply to predictions
binary_predictions = (binary_preds > thresholds_array).astype(int)

# Then recompute EM:
em_ratio = np.mean(np.all(binary_predictions == y_true, axis=1))
print(f"Exact Match (EM) Ratio with optimal thresholds: {em_ratio:.4f}")
# Out:
# Exact Match (EM) Ratio with optimal thresholds: 0.1981

# %%
optimal_thresholds = [0.5]*8
thresholds_array = np.array(optimal_thresholds)
#genre_names = ['LAIKO', 'REMPETIKO', 'ENTEXNO', 'ROCK', 'Mod LAIKO', 'POP', 'ENALLAKTIKO', 'HIPHOP/RNB']
# Apply to predictions
binary_predictions = (binary_preds > thresholds_array).astype(int)

# Then recompute EM:
em_ratio = np.mean(np.all(binary_predictions == y_true, axis=1))
print(f"Exact Match (EM) Ratio with optimal thresholds: {em_ratio:.4f}")
# Out:
# Exact Match (EM) Ratio with optimal thresholds: 0.2276

# %%
#the thresholds that are optimal for f1 scores are not also optimal for EM

# %%
class ECALayer(layers.Layer):
    def __init__(self, k_size=3, **kwargs):  # Fixed 'init' to '__init__'
        super(ECALayer, self).__init__(**kwargs)
        self.k_size = k_size

    def build(self, input_shape):
        self.conv1d = layers.Conv1D(
            filters=1,
            kernel_size=self.k_size,
            padding='same',
            use_bias=False
        )
        super(ECALayer, self).build(input_shape)

    def call(self, inputs):
        y = tf.reduce_mean(inputs, axis=[1, 2])  # [batch, C]
        y = tf.expand_dims(y, axis=-1)          # [batch, C, 1]
        y = self.conv1d(y)                      # [batch, C, 1]
        y = tf.nn.sigmoid(y)                    # [batch, C, 1]
        y = tf.reshape(y, [-1, 1, 1, inputs.shape[-1]])  # [batch, 1, 1, C]
        return inputs * y

def residual_block(x, filters, kernel_size=3, stride=1, activation='relu'):
    shortcut = x
    x = layers.Conv2D(filters, kernel_size, strides=stride, padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(filters, kernel_size+2, strides=1, padding='same')(x)
    x = layers.BatchNormalization()(x)
    
    if stride != 1 or shortcut.shape[-1] != filters:
        shortcut = layers.Conv2D(filters, 1, strides=stride, padding='same')(shortcut)
        shortcut = layers.BatchNormalization()(shortcut)
    
    x = layers.Add()([shortcut, x])
    x = layers.Activation(activation)(x)
    return x

# %%
def model_hybrid_ECA(input_shape, dense_dim, num_classes):
    inputs = layers.Input(shape=input_shape)
    
    # First block
    x = layers.Conv2D(32, (3, 3), padding='same', kernel_initializer='he_normal')(inputs)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    
    # Residual blocks with pooling
    x = residual_block(x, 32)
    x = layers.MaxPooling2D((2, 4))(x)
    x = layers.Dropout(0.2)(x)
    
    x = residual_block(x, 64, stride=2)
    # Simple attention - just ECA
    x = ECALayer()(x)
    x = layers.MaxPooling2D((2, 4))(x)
    x = layers.Dropout(0.25)(x)
    
    x = residual_block(x, 128, stride=2)
    x = layers.AveragePooling2D((2, 5))(x)
    x = layers.Dropout(0.3)(x)
    
    # Global features
    x = layers.GlobalAveragePooling2D()(x)
    
    # Shared dense layer
    shared_features = layers.Dense(256, activation='relu', 
                     kernel_regularizer=tf.keras.regularizers.l2(0.001))(x)
    shared_features = layers.Dropout(0.5)(shared_features)
    
    # Embedding path
    dense_embedding = layers.Dense(dense_dim, name='dense_embedding',
                              kernel_regularizer=tf.keras.regularizers.l2(0.0005))(shared_features)
    dense_out = layers.Lambda(lambda t: tf.nn.l2_normalize(t, axis=-1), 
                              name='dense_output')(dense_embedding)
    
    # Classification path - with connection to embedding using both shared features and embedding
    classification_input = layers.Concatenate()([shared_features, dense_embedding])
    binary_out = layers.Dense(8, activation='sigmoid', name='binary_output')(classification_input)
    
    return models.Model(inputs, [dense_out, binary_out])
