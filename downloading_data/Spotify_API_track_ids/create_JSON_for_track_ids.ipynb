# %%
import os
import json

# %%
raw_data = open('song_ids.txt', 'r')

# %%
list_of_song_ids = []

# %%
for line in raw_data:
    list_of_song_ids.append(line)

# %%
with open("track_ids.json", "w") as f:
    json.dump(list_of_song_ids, f)
